# %%
# Part 1: Load LOS Data and Preprocess

import pandas as pd
import numpy as np
import sqlalchemy
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.impute import SimpleImputer
# from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# import joblib

# %%
# Database connection details
db_username = 'ml_db'
db_password = 'pass%401234'
db_host = '10.192.5.43'
db_port = '5432'
db_name = 'postgres'

# %%
# Create a connection string and engine
conn_string = f"postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}"
engine = sqlalchemy.create_engine(conn_string)

# %%
try:
    print("--- Loading LOS Data from PostgreSQL ---")
    query = """
    SELECT *
    FROM "Ashirvad"
    WHERE "LOAN_DATE" BETWEEN '2023-01-01' AND '2023-12-31';
    """
    df_los = pd.read_sql_query(query, con=engine)
    print(f"LOS Data loaded. Total shape: {df_los.shape}")
except Exception as e:
    print(f"Database connection or query failed: {e}")
    df_los = pd.DataFrame()
# Out:
# --- Loading LOS Data from PostgreSQL ---
# LOS Data loaded. Total shape: (2002124, 52)

# %%
df_los
# Out:
#          CUSTOMER_ID           CUSTOMER_NAME         LOAN_ID DATE_OF_BIRTH  \
# 0        31708009267                  PRVESH  1708UNSL008893    1969-01-01
# 1        31954010446                   PRIYA  1954UNSL003554    1998-01-01
# 2        31752010269               PUJA PAUL  1752UNSL004687    1997-01-01
# 3        31308008340    SUKRITA KUMARI KEWAT  1308UNSL004853    1997-01-01
# 4        31793014825  ANSHIKA NILESH CHIMOTE  1793UNSL007617    2001-01-01
# ...              ...                     ...             ...           ...
# 2002119  32011006124       KAMINI RAJBONGSHI  2011UNSL002819    1982-01-01
# 2002120  31047015235            AMUTHA SEKAR  1047UNSL004606    1983-01-01
# 2002121  31685011428                 RASHIDA  1685UNSL011475    1988-01-01
# 2002122  32759001718                    RENU  2759UNSL001527    1995-01-01
# 2002123  31057023594               JOTHIMANI  1057UNSL005263    2000-01-01
#
#          BRANCH_ID   BRANCH_NAME  TEMP_CUST_ID        PHONE1        PHONE2  \
# 0             1708        SHAMLI       7630121  8.449829e+09    8864733755
# 1             1954     TARANAGAR       7628416  7.023173e+09    7023172761
# 2             1752    PAYRADANGA       7640503  8.101372e+09    9872668596
# 3             1308        KASDOL       7619430  9.303478e+09    9303477986
# 4             1793        NAGPUR       6840083  9.209255e+09  8446257897.0
# ...            ...           ...           ...           ...           ...
# 2002119       2011       NALBARI       3498743  9.127567e+09          None
# 2002120       1047  MUDUKULATHUR       7194289  7.639632e+09    7639632263
# 2002121       1685       KHATULI       7220803  9.058514e+09    8882822299
# 2002122       2759  KHERAGARH-GL       7227644  8.307145e+09    8307145166
# 2002123       1057      KOTAGIRI       7226747  9.159115e+09    9793563864
#
#         HOUSE_NAME  ... APPLICATION_ID        LOAN_PURPOSE  \
# 0             None  ...       17513464           Tailoring
# 1             None  ...       18114986  Agri - Agriculture
# 2                0  ...       18305121  Agri - Agriculture
# 3             None  ...       17928665  Agri - Agriculture
# 4             None  ...        8384146              Tailor
# ...            ...  ...            ...                 ...
# 2002119       None  ...       15907358             Product
# 2002120     NO 362  ...       12578748  Agri - Agriculture
# 2002121         77  ...       14513783          Books Shop
# 2002122          0  ...       14221717  Agri - Agriculture
# 2002123          0  ...       14263928  Agri - Agriculture
#
#         CUSTOMER_GRADING_SCORE TENURE_in_months emi_paid  \
# 0                         22.0               24     15.0
# 1                         37.0               24     15.0
# 2                         42.0               24     15.0
# 3                         62.0               24     15.0
# 4                          NaN               24     21.0
# ...                        ...              ...      ...
# 2002119                    NaN               24     17.0
# 2002120                    NaN               24     18.0
# 2002121                    NaN               24     18.0
# 2002122                    NaN               24     18.0
# 2002123                    NaN               24     18.0
#
#          loan_paid_percentage NPA_STATUS_UPDATED  NPA_STATUS_UPDATED_1  \
# 0                       62.50            UNKNOWN                  GOOD
# 1                       62.50            UNKNOWN                  GOOD
# 2                       62.50            UNKNOWN                  GOOD
# 3                       62.50            UNKNOWN                  GOOD
# 4                       87.50               GOOD                  GOOD
# ...                       ...                ...                   ...
# 2002119                 70.83            UNKNOWN                  GOOD
# 2002120                 75.00            UNKNOWN                  GOOD
# 2002121                 75.00            UNKNOWN                  GOOD
# 2002122                 75.00            UNKNOWN                  GOOD
# 2002123                 75.00            UNKNOWN                  GOOD
#
#          NPA_STATUS_UPDATED_2  YEAR
# 0                     UNKNOWN  2023
# 1                     UNKNOWN  2023
# 2                     UNKNOWN  2023
# 3                     UNKNOWN  2023
# 4                        GOOD  2023
# ...                       ...   ...
# 2002119                  GOOD  2023
# 2002120                  GOOD  2023
# 2002121                  GOOD  2023
# 2002122                  GOOD  2023
# 2002123                  GOOD  2023
#
# [2002124 rows x 52 columns]

# %%
df_los[df_los.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CUSTOMER_ID, CUSTOMER_NAME, LOAN_ID, DATE_OF_BIRTH, BRANCH_ID, BRANCH_NAME, TEMP_CUST_ID, PHONE1, PHONE2, HOUSE_NAME, LOCALITY, STREET, ALT_HOUSE_NAME, ALT_LOCALITY, ALT_STREET, CENTER_ID, CENTER_NAME, PIN_CODE, ALT_PIN_CODE, TOTAL_INCOME, TOTAL_EXPENSE, CUSTOMER_FLAG, MARITAL_STATUS, MARITAL_STATUS_NAME, LOAN_DATE, LOAN_AMOUNT, TENURE, INTEREST_RATE, LOAN_STATUS, LOAN_STATUS_DESC, CLS_DT, DISBURSED_AMOUNT, CYCLE, STATE_NAME, CIBIL_ID, CIBIL_SCORE, NPA_FLAG, NPA_FROM_DATE, NPA_TO_DATE, NPA_STATUS, OCCUPATION_ID, OCCUPATION_NAME, APPLICATION_ID, LOAN_PURPOSE, CUSTOMER_GRADING_SCORE, TENURE_in_months, emi_paid, loan_paid_percentage, NPA_STATUS_UPDATED, NPA_STATUS_UPDATED_1, NPA_STATUS_UPDATED_2, YEAR]
# Index: []
#
# [0 rows x 52 columns]

# %%
df_los.columns
# Out:
# Index(['CUSTOMER_ID', 'CUSTOMER_NAME', 'LOAN_ID', 'DATE_OF_BIRTH', 'BRANCH_ID',
#        'BRANCH_NAME', 'TEMP_CUST_ID', 'PHONE1', 'PHONE2', 'HOUSE_NAME',
#        'LOCALITY', 'STREET', 'ALT_HOUSE_NAME', 'ALT_LOCALITY', 'ALT_STREET',
#        'CENTER_ID', 'CENTER_NAME', 'PIN_CODE', 'ALT_PIN_CODE', 'TOTAL_INCOME',
#        'TOTAL_EXPENSE', 'CUSTOMER_FLAG', 'MARITAL_STATUS',
#        'MARITAL_STATUS_NAME', 'LOAN_DATE', 'LOAN_AMOUNT', 'TENURE',
#        'INTEREST_RATE', 'LOAN_STATUS', 'LOAN_STATUS_DESC', 'CLS_DT',
#        'DISBURSED_AMOUNT', 'CYCLE', 'STATE_NAME', 'CIBIL_ID', 'CIBIL_SCORE',
#        'NPA_FLAG', 'NPA_FROM_DATE', 'NPA_TO_DATE', 'NPA_STATUS',
#        'OCCUPATION_ID', 'OCCUPATION_NAME', 'APPLICATION_ID', 'LOAN_PURPOSE',
#        'CUSTOMER_GRADING_SCORE', 'TENURE_in_months', 'emi_paid',
#        'loan_paid_percentage', 'NPA_STATUS_UPDATED', 'NPA_STATUS_UPDATED_1',
#        'NPA_STATUS_UPDATED_2', 'YEAR'],
#       dtype='object')

# %%
df_los.dtypes
# Out:
# CUSTOMER_ID                        int64
# CUSTOMER_NAME                     object
# LOAN_ID                           object
# DATE_OF_BIRTH             datetime64[ns]
# BRANCH_ID                          int64
# BRANCH_NAME                       object
# TEMP_CUST_ID                       int64
# PHONE1                           float64
# PHONE2                            object
# HOUSE_NAME                        object
# LOCALITY                          object
# STREET                            object
# ALT_HOUSE_NAME                    object
# ALT_LOCALITY                      object
# ALT_STREET                        object
# CENTER_ID                        float64
# CENTER_NAME                       object
# PIN_CODE                         float64
# ALT_PIN_CODE                     float64
# TOTAL_INCOME                     float64
# TOTAL_EXPENSE                    float64
# CUSTOMER_FLAG                     object
# MARITAL_STATUS                     int64
# MARITAL_STATUS_NAME               object
# LOAN_DATE                 datetime64[ns]
# LOAN_AMOUNT                        int64
# TENURE                             int64
# INTEREST_RATE                    float64
# LOAN_STATUS                        int64
# LOAN_STATUS_DESC                  object
# CLS_DT                    datetime64[ns]
# DISBURSED_AMOUNT                   int64
# CYCLE                              int64
# STATE_NAME                        object
# CIBIL_ID                         float64
# CIBIL_SCORE                      float64
# NPA_FLAG                           int64
# NPA_FROM_DATE             datetime64[ns]
# NPA_TO_DATE               datetime64[ns]
# NPA_STATUS                        object
# OCCUPATION_ID                      int64
# OCCUPATION_NAME                   object
# APPLICATION_ID                     int64
# LOAN_PURPOSE                      object
# CUSTOMER_GRADING_SCORE           float64
# TENURE_in_months                   int64
# emi_paid                         float64
# loan_paid_percentage             float64
# NPA_STATUS_UPDATED                object
# NPA_STATUS_UPDATED_1              object
# NPA_STATUS_UPDATED_2              object
# YEAR                               int64
# dtype: object

# %%
df_los['PIN_CODE'] = df_los['PIN_CODE'].astype(str)

# %%
df_los.dtypes
# Out:
# CUSTOMER_ID                        int64
# CUSTOMER_NAME                     object
# LOAN_ID                           object
# DATE_OF_BIRTH             datetime64[ns]
# BRANCH_ID                          int64
# BRANCH_NAME                       object
# TEMP_CUST_ID                       int64
# PHONE1                           float64
# PHONE2                            object
# HOUSE_NAME                        object
# LOCALITY                          object
# STREET                            object
# ALT_HOUSE_NAME                    object
# ALT_LOCALITY                      object
# ALT_STREET                        object
# CENTER_ID                        float64
# CENTER_NAME                       object
# PIN_CODE                          object
# ALT_PIN_CODE                     float64
# TOTAL_INCOME                     float64
# TOTAL_EXPENSE                    float64
# CUSTOMER_FLAG                     object
# MARITAL_STATUS                     int64
# MARITAL_STATUS_NAME               object
# LOAN_DATE                 datetime64[ns]
# LOAN_AMOUNT                        int64
# TENURE                             int64
# INTEREST_RATE                    float64
# LOAN_STATUS                        int64
# LOAN_STATUS_DESC                  object
# CLS_DT                    datetime64[ns]
# DISBURSED_AMOUNT                   int64
# CYCLE                              int64
# STATE_NAME                        object
# CIBIL_ID                         float64
# CIBIL_SCORE                      float64
# NPA_FLAG                           int64
# NPA_FROM_DATE             datetime64[ns]
# NPA_TO_DATE               datetime64[ns]
# NPA_STATUS                        object
# OCCUPATION_ID                      int64
# OCCUPATION_NAME                   object
# APPLICATION_ID                     int64
# LOAN_PURPOSE                      object
# CUSTOMER_GRADING_SCORE           float64
# TENURE_in_months                   int64
# emi_paid                         float64
# loan_paid_percentage             float64
# NPA_STATUS_UPDATED                object
# NPA_STATUS_UPDATED_1              object
# NPA_STATUS_UPDATED_2              object
# YEAR                               int64
# dtype: object

# %%
columns_to_drop = ['CUSTOMER_ID','CUSTOMER_NAME','BRANCH_ID','TEMP_CUST_ID','PHONE1', 'PHONE2','HOUSE_NAME','LOCALITY', 'STREET',
                   'ALT_HOUSE_NAME', 'ALT_LOCALITY','ALT_STREET','CENTER_ID','ALT_PIN_CODE','MARITAL_STATUS','LOAN_STATUS',
                   'LOAN_STATUS_DESC', 'CLS_DT','CIBIL_ID','NPA_FLAG', 'NPA_FROM_DATE', 'NPA_TO_DATE', 'NPA_STATUS',
                   'OCCUPATION_ID','APPLICATION_ID', 'TENURE_in_months', 'emi_paid','loan_paid_percentage', 'NPA_STATUS_UPDATED', 
                   'NPA_STATUS_UPDATED_1','NPA_STATUS_UPDATED_2','YEAR']

# %%
df_los.drop(columns=columns_to_drop, inplace=True)

# %%
df_los.columns
# Out:
# Index(['LOAN_ID', 'DATE_OF_BIRTH', 'BRANCH_NAME', 'CENTER_NAME', 'PIN_CODE',
#        'TOTAL_INCOME', 'TOTAL_EXPENSE', 'CUSTOMER_FLAG', 'MARITAL_STATUS_NAME',
#        'LOAN_DATE', 'LOAN_AMOUNT', 'TENURE', 'INTEREST_RATE',
#        'DISBURSED_AMOUNT', 'CYCLE', 'STATE_NAME', 'CIBIL_SCORE',
#        'OCCUPATION_NAME', 'LOAN_PURPOSE', 'CUSTOMER_GRADING_SCORE'],
#       dtype='object')

# %%
null_percentages = df_los.isnull().sum() / len(df_los) * 100

# %%
features_with_nulls = null_percentages[null_percentages > 0].sort_values(ascending=False)

# %%
features_with_nulls
# Out:
# CIBIL_SCORE               85.517780
# CUSTOMER_GRADING_SCORE    62.515958
# TOTAL_EXPENSE             22.424635
# TOTAL_INCOME              22.422637
# OCCUPATION_NAME            0.993695
# DATE_OF_BIRTH              0.000050
# dtype: float64

# %%
df_los.drop(columns=['CIBIL_SCORE','CUSTOMER_GRADING_SCORE'],inplace=True)

# %%
df_los.columns
# Out:
# Index(['LOAN_ID', 'DATE_OF_BIRTH', 'BRANCH_NAME', 'CENTER_NAME', 'PIN_CODE',
#        'TOTAL_INCOME', 'TOTAL_EXPENSE', 'CUSTOMER_FLAG', 'MARITAL_STATUS_NAME',
#        'LOAN_DATE', 'LOAN_AMOUNT', 'TENURE', 'INTEREST_RATE',
#        'DISBURSED_AMOUNT', 'CYCLE', 'STATE_NAME', 'OCCUPATION_NAME',
#        'LOAN_PURPOSE'],
#       dtype='object')

# %%
df_los.shape
# Out:
# (2002124, 18)

# %%
from datetime import datetime
df_los['DATE_OF_BIRTH'] = pd.to_datetime(df_los['DATE_OF_BIRTH'], errors='coerce')
df_los['LOAN_DATE'] = pd.to_datetime(df_los['LOAN_DATE'], errors='coerce')

# %%
df_los['AGE'] = (df_los['LOAN_DATE'] - df_los['DATE_OF_BIRTH']).dt.days // 365.25

# %%
#df_los.drop(columns=['DATE_OF_BIRTH', 'LOAN_DATE'], inplace=True)
df_los.drop(columns=['DATE_OF_BIRTH'], inplace=True)

# %%
df_los.columns
# Out:
# Index(['LOAN_ID', 'BRANCH_NAME', 'CENTER_NAME', 'PIN_CODE', 'TOTAL_INCOME',
#        'TOTAL_EXPENSE', 'CUSTOMER_FLAG', 'MARITAL_STATUS_NAME', 'LOAN_DATE',
#        'LOAN_AMOUNT', 'TENURE', 'INTEREST_RATE', 'DISBURSED_AMOUNT', 'CYCLE',
#        'STATE_NAME', 'OCCUPATION_NAME', 'LOAN_PURPOSE', 'AGE'],
#       dtype='object')

# %%
df_los.shape
# Out:
# (2002124, 18)

# %%
df_los["BRANCH_NAME"].nunique()
# Out:
# 1520

# %%
df_los.columns
# Out:
# Index(['LOAN_ID', 'BRANCH_NAME', 'CENTER_NAME', 'PIN_CODE', 'TOTAL_INCOME',
#        'TOTAL_EXPENSE', 'CUSTOMER_FLAG', 'MARITAL_STATUS_NAME', 'LOAN_DATE',
#        'LOAN_AMOUNT', 'TENURE', 'INTEREST_RATE', 'DISBURSED_AMOUNT', 'CYCLE',
#        'STATE_NAME', 'OCCUPATION_NAME', 'LOAN_PURPOSE', 'AGE'],
#       dtype='object')

# %%
1251647/(1251647+750477)
# Out:
# 0.6251595805254819

# %%
df_los = df_los[df_los['CUSTOMER_FLAG'] != 'X'].copy()

# %%
df_los.dtypes
# Out:
# LOAN_ID                        object
# BRANCH_NAME                    object
# CENTER_NAME                    object
# PIN_CODE                       object
# TOTAL_INCOME                  float64
# TOTAL_EXPENSE                 float64
# CUSTOMER_FLAG                  object
# MARITAL_STATUS_NAME            object
# LOAN_DATE              datetime64[ns]
# LOAN_AMOUNT                     int64
# TENURE                          int64
# INTEREST_RATE                 float64
# DISBURSED_AMOUNT                int64
# CYCLE                           int64
# STATE_NAME                     object
# OCCUPATION_NAME                object
# LOAN_PURPOSE                   object
# AGE                           float64
# dtype: object

# %%
# Assuming df_los is your current DataFrame
if not df_los.empty:
    print("--- Analyzing Categorical Columns ---")
    
    # Identify categorical columns from your remaining list
    categorical_cols = [
        'BRANCH_NAME', 'CENTER_NAME', 'PIN_CODE', 'CUSTOMER_FLAG',
        'MARITAL_STATUS_NAME', 'STATE_NAME', 'OCCUPATION_NAME',
        'LOAN_PURPOSE'
    ]

    for col in categorical_cols:
        if col in df_los.columns:
            print(f"\nAnalyzing column: '{col}'")
            # Calculate number of unique values
            unique_count = df_los[col].nunique()
            print(f"Number of unique values: {unique_count}")

            # Print the top 10 most frequent values and their counts
            if unique_count > 0:
                print("Top 10 most frequent values:")
                print(df_los[col].value_counts().head(10))
            
            # Check for null values
            null_count = df_los[col].isnull().sum()
            if null_count > 0:
                print(f"Number of null values: {null_count}")
# Out:
# --- Analyzing Categorical Columns ---
#
# Analyzing column: 'BRANCH_NAME'
# Number of unique values: 1520
# Top 10 most frequent values:
# BRANCH_NAME
# NAGPUR            4565
# ARERAJ            3899
# MASHRAK           3898
# RAXAUL            3749
# Lauriya           3692
# BANGARPET         3530
# NARKATIYA GANJ    3485
# AURANGABAD-2      3389
# KHATULI           3297
# SUGAULI           3295
# Name: count, dtype: int64
#
# Analyzing column: 'CENTER_NAME'
# Number of unique values: 321274
# Top 10 most frequent values:
# CENTER_NAME
# RAMPUR          625
# GOPALPUR        503
# RAMNAGAR        379
# NARAYANPUR      347
# BHAGWANPUR      309
# KALYANPUR       309
# GANDHI NAGAR    300
# RAGHUNATHPUR    297
# SHAHPUR         295
# LAXMIPUR        275
# Name: count, dtype: int64
#
# Analyzing column: 'PIN_CODE'
# Number of unique values: 14370
# Top 10 most frequent values:
# PIN_CODE
# 845438.0    2944
# 799004.0    2907
# 799102.0    2516
# 831002.0    2508
# 431001.0    2504
# 799211.0    2481
# 736159.0    2400
# 843128.0    2332
# 733202.0    2044
# 799003.0    2043
# Name: count, dtype: int64
#
# Analyzing column: 'CUSTOMER_FLAG'
# Number of unique values: 4
# Top 10 most frequent values:
# CUSTOMER_FLAG
# A    1903518
# D      35079
# C      27146
# B      19439
# Name: count, dtype: int64
#
# Analyzing column: 'MARITAL_STATUS_NAME'
# Number of unique values: 6
# Top 10 most frequent values:
# MARITAL_STATUS_NAME
# MARRIED      1958075
# WIDOW          22273
# UNMARRIED       2864
# SINGLE           987
# DIVORCED         851
# UNTAGGED         132
# Name: count, dtype: int64
#
# Analyzing column: 'STATE_NAME'
# Number of unique values: 23
# Top 10 most frequent values:
# STATE_NAME
# BIHAR             280013
# TAMIL NADU        257144
# WEST BENGAL       245498
# KARNATAKA         176369
# UTTAR PRADESH     153134
# ODISHA            113369
# MADHYA PRADESH    107590
# KERALA            101778
# JHARKHAND          97831
# RAJASTHAN          96563
# Name: count, dtype: int64
#
# Analyzing column: 'OCCUPATION_NAME'
# Number of unique values: 84
# Top 10 most frequent values:
# OCCUPATION_NAME
# AGRI INPUT                            641401
# AGRICULTURE AND RELATED INPUTS        479024
# ANIMAL HUSBANDRY                      228917
# AGRICULTURE                           120171
# OTHERS                                 90354
# CONSTRUCTION (SKILLED) LABOUR          42965
# FISHING                                40538
# CROP PRODUCTION                        33384
# PERSONAL SERVICES                      32523
# CONSTRUCTION (NON-SKILLED) LABOUR      29724
# Name: count, dtype: int64
# Number of null values: 19874
#
# Analyzing column: 'LOAN_PURPOSE'
# Number of unique values: 168
# Top 10 most frequent values:
# LOAN_PURPOSE
# Agri - Agriculture         1416130
# Agri - Animal Husbandry     116431
# Agri - Dairy                113437
# Petty Shop                   70272
# Cloth Business               51622
# Vegetable Vending            21526
# Busket Making                17858
# Tailoring                    14612
# Product                      11753
# Beauty Parlour               11449
# Name: count, dtype: int64

# %%
# Assuming df_los is your current DataFrame with all columns
if not df_los.empty:
    print("--- Analyzing Missing Values ---")
    
    # Calculate the percentage of null values for each column
    null_percentages = df_los.isnull().sum() / len(df_los) * 100
    
    # Filter to show only columns with missing data and sort them
    missing_data_summary = null_percentages[null_percentages > 0].sort_values(ascending=False)
    
    if missing_data_summary.empty:
        print("No missing values found in the DataFrame.")
    else:
        print("Percentage of missing values per column:")
        print(missing_data_summary)
# Out:
# --- Analyzing Missing Values ---
# Percentage of missing values per column:
# TOTAL_EXPENSE      22.381474
# TOTAL_INCOME       22.379459
# OCCUPATION_NAME     1.001117
# AGE                 0.000050
# dtype: float64

# %%
df_los["OCCUPATION_NAME"].value_counts()
# Out:
# OCCUPATION_NAME
# AGRI INPUT                        641401
# AGRICULTURE AND RELATED INPUTS    479024
# ANIMAL HUSBANDRY                  228917
# AGRICULTURE                       120171
# OTHERS                             90354
#                                    ...
# RECREATIONAL SERVICES                 44
# AGRO BASED INDUSTRY                   29
# LIFESTYLE                             26
# ELECTRONICS AND COMPUTERS             24
# PUBLIC ADMINSTRATION                  14
# Name: count, Length: 84, dtype: int64

# %%
df_los["OCCUPATION_NAME"].unique()
# Out:
# array(['ANIMAL HUSBANDRY', 'AGRI INPUT', 'CONSTRUCTION (SKILLED) LABOUR',
#        'OTHERS', 'CROP PRODUCTION', 'AGRICULTURE AND RELATED INPUTS',
#        'FISHING', 'FISHERY', None, 'OTHER SALARIED JOBS', 'AGRICULTURE',
#        'CONSTRUCTION (NON-SKILLED) LABOUR ', 'HOUSE HELP', 'AUTOMOBILE',
#        'SMALL BUSINESS', 'FOOD AND BEVERAGES', 'EDUCATION', 'FORESTRY',
#        'PERSONAL SERVICES', 'RETAIL', 'DISTRIBUTION', 'AGRI LABOUR',
#        'HEALTH', 'FOOD MANUFACTERING AND PROCESSING',
#        'ELECTRONIC AND ELECTRICAL PRODUCTS',
#        'BANKING AND FINANCIAL SERVICES', 'WOOD AND WOOD PRODUCTS',
#        'WHOLESALE', 'SELF EMPLOYMENT', 'GEMS AND JEWELLERY',
#        'TEXTILE AND APPARELS', 'ELECTRONIC/ELECTRICAL PRODUCTS',
#        'PHARMACEUTICALS, MEDICINAL AND BOTANICAL PRODUCTS',
#        'POST-HARVEST ACTIVITIES', 'MANUFACTURING', 'VEHICLES',
#        'LEATHER AND LEATHER PRODUCTS', 'HOME MAKER',
#        'INFORMATION AND COMMUNICATION', 'SOCIAL WORK',
#        'WOOD, PULP AND PAPER', 'PAPER, PAPER PRODUCTS AND PRINTING',
#        'TOBACCO PRODUCTS', 'LEATHER AND RELATED PRODUCTS',
#        'RUBBER AND PLASTICS PRODUCTS', 'TRAVEL AND HOSPITALITY',
#        'MUSICAL INSTRUMENTS',
#        'PETROLEUM, COAL, CHEMICALS, GLASS, CERAMICS, METALS AND MINERALS',
#        'OFFICE ADMINISTRATION', 'VEHICLES PARTS AND TRANSPORT EQUIPMENTS',
#        'TRANSPORTATION', 'POSTAL OR COURIER SERVICES',
#        'SPORTS, GAMES AND TOYS', 'SECURITY SERVICES',
#        'REPAIR AND MAINTENANCE', 'WASTE MANAGEMENT',
#        'WAREHOUSING AND STORAGE', 'RECREATIONAL SERVICES',
#        'UTILITIES: GAS/ELECTRICITY/WATER/SEWAGE', 'TRADING',
#        'DAILY WAGE LABOUR', 'TOY MANUFACTURING', 'NO JOB', 'AGGREGATOR',
#        'DEPENDENT ON SPOUSE', 'POTTERY/CLAY',
#        'CONSTRUCTION AND REAL ESTATE', 'PRIVATE EMPLOYEE',
#        'FASHION-GARMENTS/APPARELS/OTHERS', 'AGRO BASED INDUSTRY',
#        'FOOD PRODUCTION AND PROCESSING', 'FOOD INDUSTRY',
#        'TRANSPORTATION, TRAVEL& TOURISM', 'BEAUTY & COSMETICS',
#        'PETROLEUM, CHEMICALS,GLASS,CERAMICS, METALS AND MINERALS',
#        'METAL INDUSTRY', 'AGRI SERVICES', 'AGRO PROCESSING',
#        'RETAIL SECTOR & SHOPS', 'ELECTRONICS AND ELECTRIC', 'ELECTRONICS',
#        'PUBLIC ADMINSTRATION', 'PAPER AND PLASTIC',
#        'ELECTRONICS AND COMPUTERS', 'LIFESTYLE'], dtype=object)

# %%
df_los[df_los["OCCUPATION_NAME"].isna()]
# Out:
#                 LOAN_ID           BRANCH_NAME               CENTER_NAME  \
# 89       1698UNSL007134            SAHARANPUR                       MAD
# 117      1635UNSL004418           COOCH BEHAR  LOVELY(BANG CHATRA ROAD)
# 129      1637UNSL005943          KAMAKHYAGURI       BOCHAMARI KISHALAYA
# 137      1799UNSL003738            HINGANGHAT                 KHARWAD A
# 181      2013UNSL002201      BASISTHA CHARALI           KACHARIBASTI 01
# ...                 ...                   ...                       ...
# 2002072  1669UNSL005038        SAKUNTALA PARK              UTTARGANIPUR
# 2002074  1669UNSL004818        SAKUNTALA PARK  MAHENDRA BANERJEE ROAD 1
# 2002081  1718UNSL004470  ISLAMPUR MAHARASHTRA                  AITAVADE
# 2002082  1890UNSL002692             MANGALWAR      SAYRA HARNATH PURA 2
# 2002119  2011UNSL002819               NALBARI                 POKOWA 02
#
#          PIN_CODE  TOTAL_INCOME  TOTAL_EXPENSE CUSTOMER_FLAG  \
# 89       247001.0       20000.0         2860.0             A
# 117      736101.0           0.0            0.0             D
# 129      736159.0           0.0            0.0             D
# 137      442907.0           0.0            0.0             D
# 181      781029.0           0.0            0.0             D
# ...           ...           ...            ...           ...
# 2002072  700141.0       23500.0         4640.0             D
# 2002074  700060.0       21500.0         3810.0             C
# 2002081  415401.0       20500.0         4060.0             D
# 2002082  312404.0       21500.0         3810.0             D
# 2002119  781335.0           0.0            0.0             D
#
#         MARITAL_STATUS_NAME  LOAN_DATE  LOAN_AMOUNT  TENURE  INTEREST_RATE  \
# 89                  MARRIED 2023-09-11        50000       2           25.0
# 117                 MARRIED 2023-08-31        69000       2           25.0
# 129                 MARRIED 2023-08-31        63000       2           25.0
# 137                 MARRIED 2023-08-31        52000       2           25.0
# 181                 MARRIED 2023-08-31        54000       2           25.0
# ...                     ...        ...          ...     ...            ...
# 2002072             MARRIED 2023-05-31        17000       2           25.0
# 2002074             MARRIED 2023-04-29        40000       2           25.0
# 2002081             MARRIED 2023-05-31        22000       2           25.0
# 2002082             MARRIED 2023-04-29        28000       2           25.0
# 2002119             MARRIED 2023-08-31        40000       2           25.0
#
#          DISBURSED_AMOUNT  CYCLE     STATE_NAME OCCUPATION_NAME  \
# 89                  50000      2  UTTAR PRADESH            None
# 117                 69000      3    WEST BENGAL            None
# 129                 63000      5    WEST BENGAL            None
# 137                 52000      4    MAHARASHTRA            None
# 181                 54000      3          ASSAM            None
# ...                   ...    ...            ...             ...
# 2002072             17000      3    WEST BENGAL            None
# 2002074             40000      4    WEST BENGAL            None
# 2002081             22000      4    MAHARASHTRA            None
# 2002082             28000      3      RAJASTHAN            None
# 2002119             40000      3          ASSAM            None
#
#                LOAN_PURPOSE   AGE
# 89                   Others  49.0
# 117                 Product  58.0
# 129            Grocery Shop  55.0
# 137                  Others  38.0
# 181                 Product  43.0
# ...                     ...   ...
# 2002072         Fish Vendor  36.0
# 2002074  Agri - Agriculture  47.0
# 2002081   Vegetable Vending  40.0
# 2002082  Agri - Agriculture  27.0
# 2002119             Product  41.0
#
# [19874 rows x 18 columns]

# %%
df_los["OCCUPATION_NAME"].unique()
# Out:
# array(['ANIMAL HUSBANDRY', 'AGRI INPUT', 'CONSTRUCTION (SKILLED) LABOUR',
#        'OTHERS', 'CROP PRODUCTION', 'AGRICULTURE AND RELATED INPUTS',
#        'FISHING', 'FISHERY', None, 'OTHER SALARIED JOBS', 'AGRICULTURE',
#        'CONSTRUCTION (NON-SKILLED) LABOUR ', 'HOUSE HELP', 'AUTOMOBILE',
#        'SMALL BUSINESS', 'FOOD AND BEVERAGES', 'EDUCATION', 'FORESTRY',
#        'PERSONAL SERVICES', 'RETAIL', 'DISTRIBUTION', 'AGRI LABOUR',
#        'HEALTH', 'FOOD MANUFACTERING AND PROCESSING',
#        'ELECTRONIC AND ELECTRICAL PRODUCTS',
#        'BANKING AND FINANCIAL SERVICES', 'WOOD AND WOOD PRODUCTS',
#        'WHOLESALE', 'SELF EMPLOYMENT', 'GEMS AND JEWELLERY',
#        'TEXTILE AND APPARELS', 'ELECTRONIC/ELECTRICAL PRODUCTS',
#        'PHARMACEUTICALS, MEDICINAL AND BOTANICAL PRODUCTS',
#        'POST-HARVEST ACTIVITIES', 'MANUFACTURING', 'VEHICLES',
#        'LEATHER AND LEATHER PRODUCTS', 'HOME MAKER',
#        'INFORMATION AND COMMUNICATION', 'SOCIAL WORK',
#        'WOOD, PULP AND PAPER', 'PAPER, PAPER PRODUCTS AND PRINTING',
#        'TOBACCO PRODUCTS', 'LEATHER AND RELATED PRODUCTS',
#        'RUBBER AND PLASTICS PRODUCTS', 'TRAVEL AND HOSPITALITY',
#        'MUSICAL INSTRUMENTS',
#        'PETROLEUM, COAL, CHEMICALS, GLASS, CERAMICS, METALS AND MINERALS',
#        'OFFICE ADMINISTRATION', 'VEHICLES PARTS AND TRANSPORT EQUIPMENTS',
#        'TRANSPORTATION', 'POSTAL OR COURIER SERVICES',
#        'SPORTS, GAMES AND TOYS', 'SECURITY SERVICES',
#        'REPAIR AND MAINTENANCE', 'WASTE MANAGEMENT',
#        'WAREHOUSING AND STORAGE', 'RECREATIONAL SERVICES',
#        'UTILITIES: GAS/ELECTRICITY/WATER/SEWAGE', 'TRADING',
#        'DAILY WAGE LABOUR', 'TOY MANUFACTURING', 'NO JOB', 'AGGREGATOR',
#        'DEPENDENT ON SPOUSE', 'POTTERY/CLAY',
#        'CONSTRUCTION AND REAL ESTATE', 'PRIVATE EMPLOYEE',
#        'FASHION-GARMENTS/APPARELS/OTHERS', 'AGRO BASED INDUSTRY',
#        'FOOD PRODUCTION AND PROCESSING', 'FOOD INDUSTRY',
#        'TRANSPORTATION, TRAVEL& TOURISM', 'BEAUTY & COSMETICS',
#        'PETROLEUM, CHEMICALS,GLASS,CERAMICS, METALS AND MINERALS',
#        'METAL INDUSTRY', 'AGRI SERVICES', 'AGRO PROCESSING',
#        'RETAIL SECTOR & SHOPS', 'ELECTRONICS AND ELECTRIC', 'ELECTRONICS',
#        'PUBLIC ADMINSTRATION', 'PAPER AND PLASTIC',
#        'ELECTRONICS AND COMPUTERS', 'LIFESTYLE'], dtype=object)

# %%
expense_median=df_los["TOTAL_EXPENSE"].median()

# %%
expense_median
# Out:
# 1760.0

# %%
income_median= df_los["TOTAL_INCOME"].median()

# %%
income_median
# Out:
# 20000.0

# %%
age_median= df_los["AGE"].median()

# %%
age_median
# Out:
# 38.0

# %%
if not df_los.empty:
    print("--- Continuing LOS Data Preprocessing ---")
    
    # --- Step 1: Drop high-cardinality and irrelevant columns ---
    # We will handle PIN_CODE, OCCUPATION_NAME, LOAN_PURPOSE later with target encoding
    columns_to_drop = ['BRANCH_NAME', 'CENTER_NAME']
    df_los.drop(columns=columns_to_drop, errors='ignore', inplace=True)
    
    # --- Step 2: Handle missing values with indicator flags ---
    numerical_cols_to_impute = ['TOTAL_EXPENSE', 'TOTAL_INCOME', 'AGE']
    for col in numerical_cols_to_impute:
        if df_los[col].isnull().sum() > 0:
            #df_los[f'{col}_MISSING'] = df_los[col].isnull().astype(int)
            median_val = df_los[col].median()
            # Corrected line to avoid the warning:
            df_los[col] = df_los[col].fillna(median_val)

    categorical_col_to_impute = 'OCCUPATION_NAME'
    if df_los[categorical_col_to_impute].isnull().sum() > 0:
        #df_los[f'{categorical_col_to_impute}_MISSING'] = df_los[categorical_col_to_impute].isnull().astype(int)
        # Corrected line to avoid the warning:
        df_los[categorical_col_to_impute] = df_los[categorical_col_to_impute].fillna('UNKNOWN')
    # --- Corrected code to handle marital status ---
    df_los['MARITAL_STATUS_NAME'] = df_los['MARITAL_STATUS_NAME'].replace(['UNMARRIED', 'SINGLE'], 'UNMARRIED/SINGLE')
        
    #print("\nMissing value imputation complete with indicator flags.")
    print("\nMissing value imputation complete with consolidation.")


    print("New value counts for MARITAL_STATUS_NAME:")
    print(df_los['MARITAL_STATUS_NAME'].value_counts())

    # --- Step 3: Segregate features by processing type ---
    # Separate the key identifier column for later use
    # id_col = 'LOAN_ID'
    # df_los_ids = df_los[[id_col]].copy()
    
    # Define columns for each preprocessing method
    # target_encode_cols = ['PIN_CODE', 'OCCUPATION_NAME', 'LOAN_PURPOSE']
    # ohe_cols = ['CUSTOMER_FLAG', 'MARITAL_STATUS_NAME', 'STATE_NAME']
    
    # The remaining columns are numerical
    # all_cols = list(df_los.columns)
    # numerical_cols = [col for col in all_cols if col not in ohe_cols + target_encode_cols + [id_col]]

    # Create a separate DataFrame for the columns to be passed through untouched
    # df_los_passthrough = df_los[target_encode_cols + [id_col]].copy()

    # --- Step 4: Create and apply a preprocessing pipeline ---
    # numerical_transformer = Pipeline(steps=[
    #     ('scaler', StandardScaler())
    # ])
    
    # categorical_transformer = Pipeline(steps=[
    #     ('onehot', OneHotEncoder(handle_unknown='ignore'))
    # ])
    
    # preprocessor = ColumnTransformer(
    #     transformers=[
    #         ('num', numerical_transformer, numerical_cols),
    #         ('cat', categorical_transformer, ohe_cols)
    #     ],
    #     remainder='drop'  # Explicitly drop columns not in a transformer
    # )
    
    # Fit and transform the numerical and OHE columns only
    # df_los_features_to_process = df_los[numerical_cols + ohe_cols].copy()
    # df_processed_array = preprocessor.fit_transform(df_los_features_to_process)
    
    # Get the names of the new encoded columns
    # new_cat_features = preprocessor.named_transformers_['cat'].named_steps['onehot'].get_feature_names_out(ohe_cols)
    # all_feature_names = numerical_cols + list(new_cat_features)

    # Convert the processed array back to a DataFrame
    #df_los_final = pd.DataFrame(df_processed_array, columns=all_feature_names)

    # Re-attach the passthrough columns
    # df_los_final = pd.concat([df_los_final, df_los_passthrough.reset_index(drop=True)], axis=1)
    print("Final data types before saving:")
    print(df_los.dtypes)
            
    # --- Step 5: Save the preprocessed DataFrame and the preprocessor object ---
    df_los.to_csv('los_cleaned.csv', index=False)

    #df_los_final.to_csv('los_preprocessed.csv', index=False)

    #joblib.dump(preprocessor, 'los_preprocessor.pkl')

    print("\nComprehensive LOS data cleaning complete.")
    print("Final DataFrame saved to 'los_cleaned.csv'.")
    print("All scaling and encoding is deferred to '3_hybrid_data_prep.ipynb'.")
    print("\nNext, we will move on to the LMS data preparation.")
# Out:
# --- Continuing LOS Data Preprocessing ---
#
# Missing value imputation complete with consolidation.
# New value counts for MARITAL_STATUS_NAME:
# MARITAL_STATUS_NAME
# MARRIED             1958075
# WIDOW                 22273
# UNMARRIED/SINGLE       3851
# DIVORCED                851
# UNTAGGED                132
# Name: count, dtype: int64
# Final data types before saving:
# LOAN_ID                        object
# PIN_CODE                       object
# TOTAL_INCOME                  float64
# TOTAL_EXPENSE                 float64
# CUSTOMER_FLAG                  object
# MARITAL_STATUS_NAME            object
# LOAN_DATE              datetime64[ns]
# LOAN_AMOUNT                     int64
# TENURE                          int64
# INTEREST_RATE                 float64
# DISBURSED_AMOUNT                int64
# CYCLE                           int64
# STATE_NAME                     object
# OCCUPATION_NAME                object
# LOAN_PURPOSE                   object
# AGE                           float64
# dtype: object
#
# Comprehensive LOS data cleaning complete.
# Final DataFrame saved to 'los_cleaned.csv'.
# All scaling and encoding is deferred to '3_hybrid_data_prep.ipynb'.
#
# Next, we will move on to the LMS data preparation.

# %%
#df_los_final.columns
df_los.columns
# Out:
# Index(['LOAN_ID', 'PIN_CODE', 'TOTAL_INCOME', 'TOTAL_EXPENSE', 'CUSTOMER_FLAG',
#        'MARITAL_STATUS_NAME', 'LOAN_DATE', 'LOAN_AMOUNT', 'TENURE',
#        'INTEREST_RATE', 'DISBURSED_AMOUNT', 'CYCLE', 'STATE_NAME',
#        'OCCUPATION_NAME', 'LOAN_PURPOSE', 'AGE'],
#       dtype='object')

# %%
#df_los_final.shape
df_los.shape
# Out:
# (1985182, 16)

# %%
2002124-1985182
# Out:
# 16942

# %%
# Load the complete preprocessed data from the CSV file
df_los_cleaned = pd.read_csv('los_cleaned.csv')

# Verify the shape to confirm all records are loaded
print(f"Loaded cleaned data with shape: {df_los_cleaned.shape}")
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 2
#
#       1 # Load the complete preprocessed data from the CSV file
#
# ----> 2 df_los_cleaned = pd.read_csv('los_cleaned.csv')
#
#       4 # Verify the shape to confirm all records are loaded
#
#       5 print(f"Loaded cleaned data with shape: {df_los_cleaned.shape}")
#
#
#
# NameError: name 'pd' is not defined

# %%
df_los_cleaned.head()
# Out:
#           LOAN_ID  PIN_CODE  TOTAL_INCOME  TOTAL_EXPENSE CUSTOMER_FLAG  \
# 0  1854UNSL009563  852114.0       25000.0         1760.0             A
# 1  2040UNSL002256  757036.0       21000.0          300.0             A
# 2  1715UNSL001385  416211.0           0.0            0.0             D
# 3  2651UNSL003253  123401.0       22000.0         2910.0             A
# 4  1165UNSL009368  571301.0       17500.0         2160.0             A
#
#   MARITAL_STATUS_NAME   LOAN_DATE  LOAN_AMOUNT  TENURE  INTEREST_RATE  \
# 0             MARRIED  2023-06-20        40000       2           25.0
# 1             MARRIED  2023-06-13        40000       2           25.0
# 2             MARRIED  2023-08-31        44000       2           25.0
# 3             MARRIED  2023-11-07        50000       2           25.0
# 4             MARRIED  2023-10-25        70000       3           25.0
#
#    DISBURSED_AMOUNT  CYCLE   STATE_NAME                 OCCUPATION_NAME  \
# 0             40000      1        BIHAR                      AGRI INPUT
# 1             40000      1       ODISHA  AGRICULTURE AND RELATED INPUTS
# 2             44000      4  MAHARASHTRA                         UNKNOWN
# 3             50000      2      HARYANA                ANIMAL HUSBANDRY
# 4             70000      2    KARNATAKA                      AGRI INPUT
#
#          LOAN_PURPOSE   AGE
# 0  Agri - Agriculture  27.0
# 1  Agri - Agriculture  51.0
# 2          Dairy Farm  33.0
# 3  Agri - Agriculture  43.0
# 4  Agri - Agriculture  40.0

# %%
df_los_cleaned.dtypes
# Out:
# LOAN_ID                 object
# PIN_CODE               float64
# TOTAL_INCOME           float64
# TOTAL_EXPENSE          float64
# CUSTOMER_FLAG           object
# MARITAL_STATUS_NAME     object
# LOAN_DATE               object
# LOAN_AMOUNT              int64
# TENURE                   int64
# INTEREST_RATE          float64
# DISBURSED_AMOUNT         int64
# CYCLE                    int64
# STATE_NAME              object
# OCCUPATION_NAME         object
# LOAN_PURPOSE            object
# AGE                    float64
# dtype: object

# %%
df_los.dtypes
# Out:
# LOAN_ID                        object
# PIN_CODE                       object
# TOTAL_INCOME                  float64
# TOTAL_EXPENSE                 float64
# CUSTOMER_FLAG                  object
# MARITAL_STATUS_NAME            object
# LOAN_DATE              datetime64[ns]
# LOAN_AMOUNT                     int64
# TENURE                          int64
# INTEREST_RATE                 float64
# DISBURSED_AMOUNT                int64
# CYCLE                           int64
# STATE_NAME                     object
# OCCUPATION_NAME                object
# LOAN_PURPOSE                   object
# AGE                           float64
# dtype: object
